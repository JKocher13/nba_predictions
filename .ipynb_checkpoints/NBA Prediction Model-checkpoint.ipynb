# %%
from datetime import date
import pandas as pd

today = date.today()
year = (today.year)
month = today.month
day = today.day
start = today
end = today

# %%
from nba_api.stats.library.parameters import *

raw_game_data = leaguegamefinder.LeagueGameFinder(league_id_nullable=LeagueIDNullable().nba, season_type_nullable=SeasonType().regular)

# %%
games = raw_game_data.get_data_frames()[0]
games['GAME_DATE'] =  pd.to_datetime(games['GAME_DATE'])
season_games = games[games.SEASON_ID == '22020']
season_games
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0       22020  1610612740               NOP   New Orleans Pelicans
# 1       22020  1610612737               ATL          Atlanta Hawks
# 2       22020  1610612742               DAL       Dallas Mavericks
# 3       22020  1610612754               IND         Indiana Pacers
# 4       22020  1610612755               PHI     Philadelphia 76ers
# ..        ...         ...               ...                    ...
# 517     22020  1610612763               MEM      Memphis Grizzlies
# 518     22020  1610612744               GSW  Golden State Warriors
# 519     22020  1610612751               BKN          Brooklyn Nets
# 520     22020  1610612747               LAL     Los Angeles Lakers
# 521     22020  1610612746               LAC            LA Clippers
#
#         GAME_ID  GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  \
# 0    0022000279 2021-01-27  NOP vs. WAS  W  241  124  ...   0.625    12    38
# 1    0022000274 2021-01-27  ATL vs. BKN  L  265  128  ...   0.893    12    25
# 2    0022000282 2021-01-27    DAL @ UTA  L  241  104  ...   0.889     4    32
# 3    0022000271 2021-01-27    IND @ CHA  W  240  116  ...   0.833    11    36
# 4    0022000276 2021-01-27  PHI vs. LAL  W  241  107  ...   0.615     7    31
# ..          ...        ...          ... ..  ...  ...  ...     ...   ...   ...
# 517  0022000017 2020-12-23  MEM vs. SAS  L  242  119  ...   0.611     5    37
# 518  0022000001 2020-12-22    GSW @ BKN  L  240   99  ...   0.652    13    34
# 519  0022000001 2020-12-22  BKN vs. GSW  W  242  125  ...   0.813    13    44
# 520  0022000002 2020-12-22  LAL vs. LAC  L  240  109  ...   0.774     8    37
# 521  0022000002 2020-12-22    LAC @ LAL  W  241  116  ...   0.737    11    29
#
#      REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0     50   27    7    4   14  17        18.0
# 1     37   29    3    7    9  18        -4.0
# 2     36   22    4    7    8  12       -12.0
# 3     47   34    1    9   12  19        10.0
# 4     38   24   10    7   11  24         1.0
# ..   ...  ...  ...  ...  ...  ..         ...
# 517   42   27    6    8   11  20       -12.0
# 518   47   26    6    6   18  24       -26.0
# 519   57   24   11    7   20  22        26.0
# 520   45   22    4    2   19  20        -7.0
# 521   40   22   10    3   16  29         7.0
#
# [522 rows x 28 columns]

# %%
import json
import requests

# %%
api_key = 'a95da0979b0f9e44f003e9658954eccf'
sport_key = 'basketball_nba'
odds_response = requests.get('https://api.the-odds-api.com/v3/odds', params={
    'api_key': api_key,
    'sport': sport_key,
    'region': 'us', # uk | us | eu | au
    'mkt': 'spreads' # h2h | spreads | totals
})

odds_json = json.loads(odds_response.text)
if not odds_json['success']:
    print(
        'There was a problem with the odds request:',
        odds_json['msg']
    )

else:
    # odds_json['data'] contains a list of live and 
    #   upcoming events and odds for different bookmakers.
    # Events are ordered by start time (live events are first)
    print()
    games_number = len(odds_json['data'])-1
    #for x in range(0,games_number):
        #print((odds_json['data'][x]))
    print((odds_json['data'][0]))
# Out:
# {'sport_key': 'basketball_nba', 'sport_nice': 'NBA', 'teams': ['Houston Rockets', 'Portland Trail Blazers'], 'commence_time': 1611880800, 'home_team': 'Houston Rockets', 'sites': [{'site_key': 'pointsbetus', 'site_nice': 'PointsBet (US)', 'last_update': 1611867861, 'odds': {'spreads': {'odds': [1.91, 1.91], 'points': ['-5.0', '5.0']}}}, {'site_key': 'betonlineag', 'site_nice': 'BetOnline.ag', 'last_update': 1611867929, 'odds': {'spreads': {'odds': [1.9, 1.9], 'points': ['-5.0', '5.0']}}}, {'site_key': 'fanduel', 'site_nice': 'FanDuel', 'last_update': 1611867975, 'odds': {'spreads': {'odds': [1.89, 1.93], 'points': ['-5.0', '5.0']}}}, {'site_key': 'lowvig', 'site_nice': 'LowVig.ag', 'last_update': 1611867938, 'odds': {'spreads': {'odds': [1.95, 1.95], 'points': ['-5', '5']}}}, {'site_key': 'bovada', 'site_nice': 'Bovada', 'last_update': 1611867921, 'odds': {'spreads': {'odds': [1.87, 1.95], 'points': ['-5.0', '5.0']}}}, {'site_key': 'gtbets', 'site_nice': 'GTbets', 'last_update': 1611867722, 'odds': {'spreads': {'odds': [1.92, 1.92], 'points': ['-5', '5']}}}, {'site_key': 'sugarhouse', 'site_nice': 'SugarHouse', 'last_update': 1611867830, 'odds': {'spreads': {'odds': [1.92, 1.89], 'points': ['-5.0', '5.0']}}}, {'site_key': 'betrivers', 'site_nice': 'BetRivers', 'last_update': 1611867819, 'odds': {'spreads': {'odds': [1.92, 1.89], 'points': ['-5.0', '5.0']}}}, {'site_key': 'unibet', 'site_nice': 'Unibet', 'last_update': 1611867743, 'odds': {'spreads': {'odds': [1.92, 1.9], 'points': ['-5.0', '5.0']}}}, {'site_key': 'draftkings', 'site_nice': 'DraftKings', 'last_update': 1611867809, 'odds': {'spreads': {'odds': [1.92, 1.89], 'points': ['-5.0', '5.0']}}}, {'site_key': 'betmgm', 'site_nice': 'BetMGM', 'last_update': 1611867862, 'odds': {'spreads': {'odds': [1.87, 1.95], 'points': ['-4.5', '4.5']}}}, {'site_key': 'mybookieag', 'site_nice': 'MyBookie.ag', 'last_update': 1611867946, 'odds': {'spreads': {'odds': [1.91, 1.91], 'points': ['-5.5', '5.5']}}}, {'site_key': 'caesars', 'site_nice': 'Caesars', 'last_update': 1611867849, 'odds': {'spreads': {'odds': [1.91, 1.91], 'points': ['-5.0', '5.0']}}}], 'sites_count': 13}

# %%
odds_json['data'][0]
# Out:
# {'sport_key': 'basketball_nba',
#  'sport_nice': 'NBA',
#  'teams': ['Houston Rockets', 'Portland Trail Blazers'],
#  'commence_time': 1611880800,
#  'home_team': 'Houston Rockets',
#  'sites': [{'site_key': 'pointsbetus',
#    'site_nice': 'PointsBet (US)',
#    'last_update': 1611867861,
#    'odds': {'spreads': {'odds': [1.91, 1.91], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'betonlineag',
#    'site_nice': 'BetOnline.ag',
#    'last_update': 1611867929,
#    'odds': {'spreads': {'odds': [1.9, 1.9], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'fanduel',
#    'site_nice': 'FanDuel',
#    'last_update': 1611867975,
#    'odds': {'spreads': {'odds': [1.89, 1.93], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'lowvig',
#    'site_nice': 'LowVig.ag',
#    'last_update': 1611867938,
#    'odds': {'spreads': {'odds': [1.95, 1.95], 'points': ['-5', '5']}}},
#   {'site_key': 'bovada',
#    'site_nice': 'Bovada',
#    'last_update': 1611867921,
#    'odds': {'spreads': {'odds': [1.87, 1.95], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'gtbets',
#    'site_nice': 'GTbets',
#    'last_update': 1611867722,
#    'odds': {'spreads': {'odds': [1.92, 1.92], 'points': ['-5', '5']}}},
#   {'site_key': 'sugarhouse',
#    'site_nice': 'SugarHouse',
#    'last_update': 1611867830,
#    'odds': {'spreads': {'odds': [1.92, 1.89], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'betrivers',
#    'site_nice': 'BetRivers',
#    'last_update': 1611867819,
#    'odds': {'spreads': {'odds': [1.92, 1.89], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'unibet',
#    'site_nice': 'Unibet',
#    'last_update': 1611867743,
#    'odds': {'spreads': {'odds': [1.92, 1.9], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'draftkings',
#    'site_nice': 'DraftKings',
#    'last_update': 1611867809,
#    'odds': {'spreads': {'odds': [1.92, 1.89], 'points': ['-5.0', '5.0']}}},
#   {'site_key': 'betmgm',
#    'site_nice': 'BetMGM',
#    'last_update': 1611867862,
#    'odds': {'spreads': {'odds': [1.87, 1.95], 'points': ['-4.5', '4.5']}}},
#   {'site_key': 'mybookieag',
#    'site_nice': 'MyBookie.ag',
#    'last_update': 1611867946,
#    'odds': {'spreads': {'odds': [1.91, 1.91], 'points': ['-5.5', '5.5']}}},
#   {'site_key': 'caesars',
#    'site_nice': 'Caesars',
#    'last_update': 1611867849,
#    'odds': {'spreads': {'odds': [1.91, 1.91], 'points': ['-5.0', '5.0']}}}],
#  'sites_count': 13}
